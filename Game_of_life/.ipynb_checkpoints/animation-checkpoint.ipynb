# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from matplotlib import animation as anim
from IPython.display import HTML
import matplotlib.patches as mpatches

# %%
periodic = []
n = 40
for i in range(n):
    name = "./testdata/finaldataabs" + str(i) + ".txt"
    t = np.loadtxt(name)
    periodic.append(t)

# %%
def create_animation(A):
    fig = plt.figure(figsize=(12,6))

    plt.title('Game of Life: periodic with 36*36, 40 iteration')

    imgs = []
    for i in range(len(A)):
        data = A[i]
        values = np.unique(data.ravel())
        im = plt.imshow(data, interpolation='none', cmap="binary")
        imgs.append([im])
    colors = [ im.cmap(im.norm(value)) for value in values]
    patches = [ mpatches.Patch(color=colors[i], label="Alive" if values[i] else "Dead" ) for i in range(len(values)) ]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

    ani = anim.ArtistAnimation(fig, imgs, interval=100, blit=True)
    plt.close(fig)  # prevent final frame plot from showing up inline below

    return ani

# %%
ani = create_animation(periodic)
print('Preparing HTML (takes a little while...)')
HTML(ani.to_jshtml())
# Out:
# Preparing HTML (takes a little while...)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img7a3502f00b0d4b1788d218d51f39111b">
#     <br>
#     <input id="_anim_slider7a3502f00b0d4b1788d218d51f39111b" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim7a3502f00b0d4b1788d218d51f39111b.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim7a3502f00b0d4b1788d218d51f39111b.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim7a3502f00b0d4b1788d218d51f39111b.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim7a3502f00b0d4b1788d218d51f39111b.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim7a3502f00b0d4b1788d218d51f39111b.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim7a3502f00b0d4b1788d218d51f39111b.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim7a3502f00b0d4b1788d218d51f39111b.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim7a3502f00b0d4b1788d218d51f39111b.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim7a3502f00b0d4b1788d218d51f39111b.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim7a3502f00b0d4b1788d218d51f39111b.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select7a3502f00b0d4b1788d218d51f39111b" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7a3502f00b0d4b1788d218d51f39111b";
#     var slider_id = "_anim_slider7a3502f00b0d4b1788d218d51f39111b";
#     var loop_select_id = "_anim_loop_select7a3502f00b0d4b1788d218d51f39111b";
#     var frames = new Array(40);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3X18zvXix/H3ZcPYxtzs1saQMmOG\
# ScrtEXUcNz+EuTlNU0o3RygUj8g5iU510tGJlU66o9Ixp5IfkvSjrB2mHyk3GdssrjVjc5PZPr8/\
# erh+XdlYms+1i9fz8fB47PreXe/vp215+3yv79dhjDECAAAAAFx21TwdAAAAAACuFhQwAAAAALCE\
# AgYAAAAAllDAAAAAAMASChgAAAAAWEIBAwAAAABLKGAAAAAAYAkFDAAAAAAsoYABAAAAgCUUMAAA\
# AACwhAIGAAAAAJZQwAAAAADAEgoYAAAAAFhCAQMAAAAASyhgAAAAAGAJBQwAAAAALKGAAQAAAIAl\
# FDAAAAAAsIQCBgAAAACWUMAAAAAAwBIKGAAAAABYQgEDAAAAAEsoYAAAAABgCQUMAAAAACyhgAEA\
# AACAJRQwAAAAALCEAgYAAAAAllDAAAAAAMASChgAAAAAWEIBAwAAAABLKGAAAAAAYAkFDAAAAAAs\
# oYABAAAAgCUUMAAAAACwhAIGAAAAAJZQwADAA7799lu1a9dOgYGBev755yu838GDBxUQEKCSkhJJ\
# 0uHDh9WtWzcFBgZq8uTJlyvuJfnss8903XXXXdK+r776qrp06eJ6HRAQoO+++66yorl588031adP\
# n3LXb9iwQZGRkZflva80sbGx2rBhg8fe/5c/HwBQFVHAAHi1ZcuWqVOnTvL391dISIg6deqkf/zj\
# HzLGeDraBT311FPq0aOHCgsL9ac//em89T169NDLL7983vLGjRurqKhIPj4+kqSUlBQ1bNhQx48f\
# 1zPPPHPZc/8aXbt21bffflspxyoqKlKzZs0q5Vi/NGrUKK1Zs8b12uFwaO/evZd8vClTpigqKkp1\
# 6tRRkyZN9MQTT7itLykp0YwZMxQREaHAwEC1a9dOBQUFbtuMGTPG7fVzzz2nZs2aqU6dOoqIiNDE\
# iRN19uxZt23mz5+vpk2byt/fXzExMdq9e/evyp2fn6/g4GC34itJH3/8sVq2bKnatWurZ8+eOnDg\
# QLnH2Llzp3r06CFJmjVrlkaPHv2rMvxa0dHRWrdunev1L38+AKAqooAB8FrPPPOMJkyYoIcffljf\
# f/+9Dh8+rIULF2rTpk06c+aMp+Nd0IEDBxQbG1spx2nVqpUcDkclpKo8vywHV5OxY8fqm2++0fHj\
# x7V582a99dZb+te//uVaP3PmTG3evFmff/65jh8/rtdff11+fn46ePCgJk6cqJMnT0qS/vd//1cP\
# P/ywJKl///7aunWrjh8/rh07dmj79u1uM6cvv/yyFi9erA8//FBFRUX64IMP1LBhw1+Ve+rUqYqJ\
# iXFblpeXp8GDB+vPf/6z8vPzlZCQoOHDh1/q0PwqV/P3EIArnAEAL1RQUGBq165tli9ffsHtPvjg\
# AxMfH28CAwNNZGSkmTlzpmvd/v37jSTzyiuvmMjISBMUFGRefPFFk5aWZtq0aWPq1q1r7rvvPrfj\
# LV682LRs2dIEBQWZPn36mMzMzHLfe+XKlaZVq1ambt26pnv37ubrr782xhjTs2dPU61aNVOzZk3j\
# 7+9vvv322/P27d69u3nppZfOW34uc3FxsUlKSjK+vr6mevXqxt/f36xdu9aUlJSYJ5980jRr1szU\
# r1/fDB061Pzwww8XHKNzPvnkE9OoUSPzxBNPmAYNGpgmTZqYN954w7X+9OnTZvLkySYqKsqEhISY\
# u+++25w8edJt37lz55rQ0FAzevRo17Jzvv76a9O9e3dTt25d06pVK7Ny5UrXury8PNO/f38TGBho\
# OnbsaGbMmGFuuukm13pJZs+ePcYYY06ePGkmTZpkGjdubOrUqWNuuukmV46f69at

# %%
non_periodic = []
n = 40
for i in range(n):
    name = "./testdata/finaldatanonpd" + str(i) + ".txt"
    t = np.loadtxt(name)
    non_periodic.append(t)

# %%
def create_animation_2(A):
    fig = plt.figure(figsize=(12,6))

    plt.title('Game of Life: non_periodic with 36*36, 40 iteration')

    imgs = []
    for i in range(len(A)):
        data = A[i]
        values = np.unique(data.ravel())
        im = plt.imshow(data, interpolation='none', cmap="binary")
        imgs.append([im])
    colors = [ im.cmap(im.norm(value)) for value in values]
    patches = [ mpatches.Patch(color=colors[i], label="Alive" if values[i] else "Dead" ) for i in range(len(values)) ]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

    ani = anim.ArtistAnimation(fig, imgs, interval=100, blit=True)
    plt.close(fig)  # prevent final frame plot from showing up inline below

    return ani

# %%
ani = create_animation_2(non_periodic)
print('Preparing HTML (takes a little while...)')
HTML(ani.to_jshtml())
# Out:
# Preparing HTML (takes a little while...)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc01f93c841ca49d3a0956773471e53d5">
#     <br>
#     <input id="_anim_sliderc01f93c841ca49d3a0956773471e53d5" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animc01f93c841ca49d3a0956773471e53d5.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectc01f93c841ca49d3a0956773471e53d5" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc01f93c841ca49d3a0956773471e53d5";
#     var slider_id = "_anim_sliderc01f93c841ca49d3a0956773471e53d5";
#     var loop_select_id = "_anim_loop_selectc01f93c841ca49d3a0956773471e53d5";
#     var frames = new Array(40);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3X98zXX/x/HnsS3TNmZsM4YhMWNO\
# TCL5kaaS5ivlVzRJ0tX1zRddJbqiXPlxla6Uil3punz7QeX7ZVeFC0lKl9bK8hX5EtO21mwYVthx\
# 9v7+4eZ8HTaW5n12eNxvN7ebnfP5fM7z83K29uzzOZ+PwxhjBAAAAAC46Gr4OgAAAAAAXC4oYAAA\
# AABgCQUMAAAAACyhgAEAAACAJRQwAAAAALCEAgYAAAAAllDAAAAAAMASChgAAAAAWEIBAwAAAABL\
# KGAAAAAAYAkFDAAAAAAsoYABAAAAgCUUMAAAAACwhAIGAAAAAJZQwAAAAADAEgoYAAAAAFhCAQMA\
# AAAASyhgAAAAAGAJBQwAAAAALKGAAQAAAIAlFDAAAAAAsIQCBgAAAACWUMAAAAAAwBIKGAAAAABY\
# QgEDAAAAAEsoYAAAAABgCQUMAAAAACyhgAEAAACAJRQwAAAAALCEAgYAAAAAllDAAAAAAMASChgA\
# AAAAWEIBAwAAAABLKGAAAAAAYAkFDAAAAAAsoYABwAXasWOHrrnmGoWFhenFF1+s9Ho//PCDQkND\
# 5Xa7JUkFBQXq3r27wsLCNHHixIsV12/ceuutWrRo0QWtGxcXp7Vr10qSZsyYodGjR1dlNC8JCQla\
# v359hc/37NlTr7322kV7/UvFp59+qlatWvk0w8V+rwDA6ShgAHxuyZIl6ty5s0JCQhQVFaXOnTvr\
# lVdekTHG19HO6c9//rN69uypI0eO6OGHHz7r+Yp+AW/SpIlKSkoUEBAgSUpLS1P9+vV1+PBhzZkz\
# 56Lnru5Wrlyp1NTU37ydyZMnX9QC9O2336pnz56SpGnTpmn48OEXvK1t27YpKSlJdevWVd26dXXT\
# TTdp27ZtXst8/fXX6t69u0JDQxUdHa25c+d6PT9t2jRlZ2d7vi4qKtL111+vevXqKTw8XF26dNHG\
# jRu91tm9e7f69eunsLAw1a9fX48++mil8m7atEnJycmKiIhQZGSk7rrrLuXn53tlCQoKUmhoqOfP\
# 7t27y93WDTfcoB07dni+Pr1EXwzr169XbGys12MX+70CAKejgAHwqTlz5mjcuHH6wx/+oJ9++kkF\
# BQWaP3++Nm7cqNLSUl/HO6e9e/cqISGhSrbTpk0bORyOKkjlv4wxKisr83UMn2jYsKGWLl2qAwcO\
# qKioSCkpKRoyZIjn+aKiIt1yyy164IEHtH//fu3atUt9+vSRdPLozaeffipJOnHihJ555hlt2rRJ\
# oaGhev3111VYWKiDBw/qscce0+23364TJ05IkkpLS5WcnKwbb7xRP/30k3JzcytdIg8ePKgxY8Yo\
# Oztbe/fuVVhYmO69916vZQYPHqySkhLPn+bNm1fFqM7pcn4PAfAjBgB8pLi42Fx55ZVm6dKl51zu\
# gw8+ME6n04SFhZnY2FgzdepUz3N79uwxkszrr79uYmNjTXh4uHn11VdNRkaGadeunalTp4556KGH\
# vLa3cOFC07p1axMeHm769OljsrOzK3zt9PR006ZNG1OnTh3To0cPs23bNmOMMb169TI1atQwNWvW\
# NCEhIWbHjh1nrdujRw/z17/+9azHT2V2uVwmNTXVBAYGmqCgIBMSEmLWrFlj3G63mTlzpmnevLmJ\
# iIgwd911l9m/f/85Z3TKxx9/bBo1amSee+45ExkZaRo0aGBef/11z/PFxcVmxIgRpn79+qZJkyZm\
# +vTpxu12G2OM+dvf/mauv/56M3HiRBMeHm7i4uLMihUrzvuaPXr0MJMmTTKdOnUytWvXNikpKV55\
# //Wvf5kuXbqYOnXqmMTERPPxxx97rTt58mTTtWtXExwcbHbu3Ok1N7fbbaZPn26a

# %%
alive_99 = []
n = 25
for i in range(n):
    name = "./testdata/finaldata99alive" + str(i) + ".txt"
    t = np.loadtxt(name)
    alive_99.append(t)

# %%
def create_animation_99alive(A):
    fig = plt.figure(figsize=(12,6))

    plt.title('Game of Life: 99% alive, 25 iteration')

    imgs = []
    for i in range(len(A)):
        data = A[i]
        values = np.unique(data.ravel())
        im = plt.imshow(data, interpolation='none', cmap="binary")
        imgs.append([im])
    colors = [ im.cmap(im.norm(value)) for value in values]
    patches = [ mpatches.Patch(color=colors[i], label="Alive" if values[i] else "Dead" ) for i in range(len(values)) ]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

    ani = anim.ArtistAnimation(fig, imgs, interval=100, blit=True)
    plt.close(fig)  # prevent final frame plot from showing up inline below

    return ani

# %%
ani = create_animation_99alive(alive_99)
print('Preparing HTML (takes a little while...)')
HTML(ani.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-17-10cc167d9b88> in <module>
# ----> 1 ani = create_animation_99alive(alive_99)
#       2 print('Preparing HTML (takes a little while...)')
#       3 HTML(ani.to_jshtml())
#
# <ipython-input-16-e2053a9558ff> in create_animation_99alive(A)
#      10         im = plt.imshow(data, interpolation='none', cmap="binary")
#      11         imgs.append([im])
# ---> 12     colors = [ im.cmap(im.norm(value)) for value in values]
#      13     patches = [ mpatches.Patch(color=colors[i], label="Alive" if values[i] else "Dead" ) for i in range(len(values)) ]
#      14     plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )
#
# UnboundLocalError: local variable 'values' referenced before assignment
