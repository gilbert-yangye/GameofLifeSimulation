# %%
import matplotlib.pyplot as plt
import numpy as np
import random
from matplotlib import animation as anim
from IPython.display import HTML
import matplotlib.patches as mpatches

# %%
periodic = []
n = 40
for i in range(n):
    name = "./testdata/finaldataabs" + str(i) + ".txt"
    t = np.loadtxt(name)
    periodic.append(t)

# %%
def create_animation(A):
    fig = plt.figure(figsize=(12,6))

    plt.title('Game of Life: periodic with 36*36, 40 iteration')

    imgs = []
    for i in range(len(A)):
        data = A[i]
        values = np.unique(data.ravel())
        im = plt.imshow(data, interpolation='none', cmap="binary")
        imgs.append([im])
    colors = [ im.cmap(im.norm(value)) for value in values]
    patches = [ mpatches.Patch(color=colors[i], label="Alive" if values[i] else "Dead" ) for i in range(len(values)) ]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

    ani = anim.ArtistAnimation(fig, imgs, interval=100, blit=True)
    plt.close(fig)  # prevent final frame plot from showing up inline below

    return ani

# %%
ani = create_animation(periodic)
print('Preparing HTML (takes a little while...)')
HTML(ani.to_jshtml())
# Out:
# Preparing HTML (takes a little while...)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgb8586a4d82b44136929fa0b8af28c62e">
#     <br>
#     <input id="_anim_sliderb8586a4d82b44136929fa0b8af28c62e" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animb8586a4d82b44136929fa0b8af28c62e.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animb8586a4d82b44136929fa0b8af28c62e.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animb8586a4d82b44136929fa0b8af28c62e.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animb8586a4d82b44136929fa0b8af28c62e.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animb8586a4d82b44136929fa0b8af28c62e.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animb8586a4d82b44136929fa0b8af28c62e.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animb8586a4d82b44136929fa0b8af28c62e.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animb8586a4d82b44136929fa0b8af28c62e.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animb8586a4d82b44136929fa0b8af28c62e.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animb8586a4d82b44136929fa0b8af28c62e.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectb8586a4d82b44136929fa0b8af28c62e" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb8586a4d82b44136929fa0b8af28c62e";
#     var slider_id = "_anim_sliderb8586a4d82b44136929fa0b8af28c62e";
#     var loop_select_id = "_anim_loop_selectb8586a4d82b44136929fa0b8af28c62e";
#     var frames = new Array(40);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3X18zvXix/H3ZcPYjcVubIaZxIxZ\
# THJym9CRmx8K0WmaUro5Qqnf4RF1fm7qpJPSiZVOuqNyjvlV+CFJP8rayfQToTK2WXMtxuZ2ts/v\
# jx6u09U2FvO5ds3r+Xh4PHZd35vr/f3s2nj7fK/v12GMMQIAAAAAXHa1PB0AAAAAAK4UFDAAAAAA\
# sIQCBgAAAACWUMAAAAAAwBIKGAAAAABYQgEDAAAAAEsoYAAAAABgCQUMAAAAACyhgAEAAACAJRQw\
# AAAAALCEAgYAAAAAllDAAAAAAMASChgAAAAAWEIBAwAAAABLKGAAAAAAYAkFDAAAAAAsoYABAAAA\
# gCUUMAAAAACwhAIGAAAAAJZQwAAAAADAEgoYAAAAAFhCAQMAAAAASyhgAAAAAGAJBQwAAAAALKGA\
# AQAAAIAlFDAAAAAAsIQCBgAAAACWUMAAAAAAwBIKGAAAAABYQgEDAAAAAEsoYAAAAABgCQUMAAAA\
# ACyhgAEAAACAJRQwAAAAALCEAgYAAAAAllDAAMADdu/erWuvvVaBgYF64YUXKr3dgQMHFBAQoJKS\
# EklSXl6eevToocDAQE2ZMuVyxb0on332mVq3bn1R277++uvq1q2b63FAQIB++OGHqorm5u2331a/\
# fv0qXL5x40ZFRUVdlteuaX7/+99ryZIlHs1wOd8rAFAVKGAAvNqyZcvUpUsX+fv7KywsTF26dNHf\
# /vY3GWM8He28nnnmGfXq1UuFhYX64x//WGZ5r1699Oqrr5Z5vlmzZioqKpKPj48kKSUlRSEhITp2\
# 7JjmzZt32XP/Ft27d9fu3burZF9FRUWKiYmpkn392pgxY7R27VrXY4fDoe++++6i9zd16lQ1bdpU\
# QUFBat68uWbNmuW2vKSkRNOnT1dkZKQCAwN17bXXqqCgwG2dsWPHuj1+/vnnFRMTo6CgIEVGRmrS\
# pEk6e/as2zrz589XixYt5O/vr9jYWO3Zs6dSeR955BG1atVKgYGBatOmjd544w235Q6HQ/7+/goI\
# CFBAQIDuvvvuCve1evVqJSUlSSpboi+H8n5OLud7BQCqAgUMgNeaN2+eJk6cqEcffVQ//vij8vLy\
# tHDhQm3evFlnzpzxdLzz2r9/v+Li4qpkP23btpXD4aiCVFXn1+XgSjJu3Dh9++23OnbsmLZs2aJ3\
# 3nlH//znP13LZ8yYoS1btujzzz/XsWPH9Oabb8rPz08HDhzQpEmTdOLECUnS//3f/+nRRx+VJA0a\
# NEhfffWVjh07ph07dmj79u1uM6evvvqqFi9erI8++khFRUX68MMPFRISUqm8/v7++uCDD3T06FEt\
# WbJEEydO1JYtW9zW2b59u4qKilRUVFTufwxcDlfyewhADWcAwAsVFBSY+vXrm+XLl593vQ8//NAk\
# JCSYwMBAExUVZWbMmOFatm/fPiPJvPbaayYqKsoEBwebl19+2aSlpZn27dubBg0amAceeMBtf4sX\
# LzZt2rQxwcHBpl+/fiYzM7PC1165cqVp27atadCggenZs6fZuXOnMcaY3r17m1q1apm6desaf39/\
# s3v37jLb9uzZ07zyyitlnj+Xubi42CQlJRlfX19Tu3Zt4+/vb9atW2dKSkrMnDlzTExMjGnYsKG5\
# 7bbbzE8//XTeMTrnk08+MU2aNDGzZs0yjRo1Ms2bNzdvvfWWa/mpU6fMlClTTNOmTU1YWJi59957\
# zYkTJ9y2nTt3rgkPDzd33HGH67lzdu7caXr27GkaNGhg2rZta1auXOlalp+fbwYNGmQCAwNN586d\
# zfTp080NN9zgWi7J7N271xhjzIkTJ8zkyZNNs2bNTFBQkLnhhhtcOX6pR48ervfH

# %%
non_periodic = []
n = 40
for i in range(n):
    name = "./testdata/finaldatanonpd" + str(i) + ".txt"
    t = np.loadtxt(name)
    non_periodic.append(t)

# %%
def create_animation_2(A):
    fig = plt.figure(figsize=(12,6))

    plt.title('Game of Life: non_periodic with 36*36, 40 iteration')

    imgs = []
    for i in range(len(A)):
        data = A[i]
        values = np.unique(data.ravel())
        im = plt.imshow(data, interpolation='none', cmap="binary")
        imgs.append([im])
    colors = [ im.cmap(im.norm(value)) for value in values]
    patches = [ mpatches.Patch(color=colors[i], label="Alive" if values[i] else "Dead" ) for i in range(len(values)) ]
    plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )

    ani = anim.ArtistAnimation(fig, imgs, interval=100, blit=True)
    plt.close(fig)  # prevent final frame plot from showing up inline below

    return ani

# %%
ani = create_animation_2(non_periodic)
print('Preparing HTML (takes a little while...)')
HTML(ani.to_jshtml())
# Out:
# Preparing HTML (takes a little while...)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgc01f93c841ca49d3a0956773471e53d5">
#     <br>
#     <input id="_anim_sliderc01f93c841ca49d3a0956773471e53d5" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animc01f93c841ca49d3a0956773471e53d5.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animc01f93c841ca49d3a0956773471e53d5.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectc01f93c841ca49d3a0956773471e53d5" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc01f93c841ca49d3a0956773471e53d5";
#     var slider_id = "_anim_sliderc01f93c841ca49d3a0956773471e53d5";
#     var loop_select_id = "_anim_loop_selectc01f93c841ca49d3a0956773471e53d5";
#     var frames = new Array(40);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAAIABJREFUeJzt3